# %%
import pandas as pd

# %%
df1 = pd.read_excel('Common2.xlsx')
elective = pd.read_excel('elective.xlsx')
student_details = pd.read_excel('student_details.xlsx')
button_labels = [f"Button {i}" for i in range(1, 21)]
electivefive = elective['Q5'].tolist()
electivesix = elective['Q6'].tolist()
electiveseven = elective['Q7'].tolist()
button = student_details['Roll'].tolist()
df1 = df1.replace("Y","1")
df1 = df1.fillna(0)
df2 = df1["Tamil"].astype(int) + df1["Aravinthan"].astype(int)
selected_buttons1 = []
selected_buttons1 = 'EPGP-15A-002'

# %%
(df2 == 2).sum()
# Out:
# 3

# %%
def countofcommon (Name1, Name2):
    df3 = df1[Name1].astype(int) + df1[Name2].astype(int)
    total = (df3 == 2).sum()
    if Name1 == Name2:
        total = 0
    return total

# %%
countofcommon("Arul","Arul")
# Out:
# 0

# %%
list = ['EPGP-15A-001','EPGP-15A-001' ,'EEC-02-Introduction to Public Policy', 'EEC-03-Agent-Based Modelling for Business and Management', 'EEC-01-Game Theory', 'EFM-01-Advanced Management Accounting', 'EFM-02-Security Analysis and Portfolio Management', 'EFM-03-Project Finance', 'EFM-04-Financial Derivatives', 'EFM-05-Management of Financial Institutions', 'EFM-06-International Finance', 'EFM-07-Valuations Mergers & Acquisitions', 'EHLM-03-Understanding Public Policy', 'EHLM-04-Advanced Business Law', 'EEC-01-Game Theory', 'EFM-08-Financial Statement Analysis', 'EFM-09-Strategic Financial Management', 'EFM-10-Entrepreneurial Finance', 'EHLM-05-Social Media – Communication and Business', 'EHLM-06-Democracy, Politics and Institutions']

# %%
student_details
# Out:
#              Roll          Name                Q5_1  \
# 0    EPGP-15A-001  EPGP-15A-001  EEC-01-Game Theory
# 1    EPGP-15A-002  EPGP-15A-002                 NaN
# 2    EPGP-15A-003  EPGP-15A-003                 NaN
# 3    EPGP-15A-004  EPGP-15A-004                 NaN
# 4    EPGP-15A-005  EPGP-15A-005  EEC-01-Game Theory
# ..            ...           ...                 ...
# 545  EPGP-15E-106  EPGP-15E-106                 NaN
# 546  EPGP-15E-107  EPGP-15E-107                 NaN
# 547  EPGP-15E-108  EPGP-15E-108                 NaN
# 548  EPGP-15E-109  EPGP-15E-109                 NaN
# 549  EPGP-15E-110  EPGP-15E-110                 NaN
#
#                                      Q5_2  \
# 0    EEC-02-Introduction to Public Policy
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4    EEC-02-Introduction to Public Policy
# ..                                    ...
# ...

# %%
A = [1,2,3,4,5,6]
B = [3, 5, 7, 9]
C = (set(A).intersection(B))
sorted(C)
# Out:
# [3, 5]

# %%
A = student_details.loc[0, :].values.flatten().tolist()
B = student_details.loc[4, :].values.flatten().tolist()
C = (set(A).intersection(B))
D = sorted(C)
len(D)
D
# Out:
# ['EEC-01-Game Theory',
#  'EEC-02-Introduction to Public Policy',
#  'EEC-03-Agent-Based Modelling for Business and Management',
#  'EFM-01-Advanced Management Accounting',
#  'EFM-02-Security Analysis and Portfolio Management',
#  'EFM-03-Project Finance',
#  'EFM-05-Management of Financial Institutions',
#  'EFM-06-International Finance',
#  'EFM-07-Valuations Mergers & Acquisitions',
#  'EFM-08-Financial Statement Analysis',
#  'EFM-09-Strategic Financial Management',
#  'EFM-10-Entrepreneurial Finance',
#  'EHLM-03-Understanding Public Policy',
#  'EHLM-04-Advanced Business Law',
#  'EHLM-05-Social Media – Communication and Business',
#  'EHLM-06-Democracy, Politics and Institutions',
#  'EIT-04-Natural Language Processing for Business']
